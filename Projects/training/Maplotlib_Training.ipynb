# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
print('matplotlib  and matplotlib.pyplot imported')
mpl.__version__
# Out:
# matplotlib  and matplotlib.pyplot imported
# '3.1.1'

# %%
plt.style.use('classic') # klassischen Matplotlib Stil

# %% [markdown]
# Mit den Befehl *%matplotlib*  (magic function )kann man inn einem Ipython notebook ähnlich wie in einer Ipython shell interaktiv Diagramme erstellen.
# Man hat dazu zwei Optionen .
# 1. *%matplotlib notebook* interaktives Daiagramm
# 2. *%matplotlib inline* statisches Diagramm

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0, 10, 100)
fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')

# %% [markdown]
# Grafiken kann man mithilte des *savefig()* in verschiedenen Formaten speichern.

# %%
fig.savefig('my_figure.png')

# %%
# !ls -lh my_figure.png
# Out:
# Der Befehl "ls" ist entweder falsch geschrieben oder
# konnte nicht gefunden werden.

# %%
from IPython.display import Image

# %%
Image('my_figure.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'ps': 'Postscript',
#  'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# # MATLAB-Stil Vs. Objektorientierte Schnittstelle

# %%
plt.figure() # Abbildng erzeugen 
# Erstes Diagramm erzeugen und Achse zuweisen
plt.subplot(2,1,1)
plt.plot(x, np.sin(x))
# Zweites Diagramm erzeugen und Achse zuweisen
plt.subplot(2,1,2)
plt.plot(x, np.cos(x))

# %%
# Raster für die Diagrammne erzeugen
# ax ist ein Array, das zwei Axes-Objekte enthält
fig, ax = plt.subplots(2)
# plot()-Methoden der Objekte aufrufen
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %% [markdown]
# # Einfache Liniendigramme

# %%
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# Bei allen Matplotlib-Diagrammen erzeugen wir zunächst ein Figure und ein Axes Objekt, die in ihrer einfachten Form folgendermaßen erzeugt werden.

# %% [markdown]
# fig = plt.figure()
# ax = plt.axes()
# x = np.linspace(0,10, 100)
# ax.plot(x, np.sin(x))

# %% [markdown]
# Alternativ können wir auch die statische Schnittstelle verwenden, die das Figure und Axes Objekt im Hintergrund automatisch erzeugt.

# %%
plt.plot(x, np.sin(x))

# %% [markdown]
# Bei mehreren Kurven in einem Diagramm rufen ir die *plot* Funktion einfach mehrmals auf

# %%
plt.plot(x, np.cos(x))
plt.plot(x, np.sin(x))

# %% [markdown]
# # Anpassen des Diagrammsbegrenzung

# %%
plt.plot(x, np.sin(x))
plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %% [markdown]
# **plt.axis()** (mit i) ist eine nützliche Funktion, die es ermöglicht, die Begrenzungen der x- und y-Achse mit einem einzigen Aufrug einzustellen.

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]) # xmin, xmax, ymin, ymax = axis([xmin, xmax, ymin, ymax])
# Out:
# [-1, 11, -1.5, 1.5]

# %% [markdown]
# Man kann auch die axis Methide verwenden um die Begrenzung automatisch eng am aktuellen Graphen auszurichten.
# Mehr unter [link](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.axis.html).

# %%
plt.plot(x, np.sin(x))
plt.axis('tight')
# Out:
# (0.0, 10.0, -0.9993845576124357, 0.9996923408861117)

# %% [markdown]
# # Diagramme beschriften

# %%
plt.plot(x, np.sin(x))
plt.title("Eine Sinuskurve")
plt.xlabel("x")
plt.ylabel("sin(x)")
# Out:
# Text(0, 0.5, 'sin(x)')

# %% [markdown]
# Wenn in einem einzigen axes Objekt mehrere Kurven angezeigt werden, ist es sinnvoll, eine Legende zur Kennzeichung der vrschiedenen Liinenarten zu erstellen. Auch hierfür bietet Marplotlib eine integriert Möglichkeit: die *plt.legend()* Methode

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')
plt.legend()

# %% [markdown]
# Beim Einsatz der objekorientierten Methode ist es oft bequemer, nicht alle Funktionen einzeln aufzurufen, sondern stattdessen die *ax.set()* Methode zu benutzen und alle EIgenschaften in einem Rutsch zuzuweisen.

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0,10), ylim=(-2,2), xlabel='x', ylabel='sin(x)', title='Ein einfaches Diagramm')
# Out:
# [(-2, 2),
#  Text(0, 0.5, 'sin(x)'),
#  (0, 10),
#  Text(0.5, 0, 'x'),
#  Text(0.5, 1.0, 'Ein einfaches Diagramm')]

# %% [markdown]
# # Verschiedene Marker

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker, label="marker='{0}'".format(marker))
    plt.legend(numpoints=1)
    plt.xlim(0,1.8)

# %% [markdown]
# # Streudiagramme

# %%
x = np.linspace(0,10,50)
y = np.sin(x)
plt.scatter(x,y,marker='o')

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T
plt.scatter(features[0], features[1], alpha=0.2, s = 100*features[3], c = iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %% [markdown]
# **plot() vs scatter()** Bei großen Datenmengen ist es durchaus besser, plt.plot vorzuziehen als plt.scatter
